# %%
#Import Libraries

import pandas as pd
from datetime import datetime
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.io as pio
pio.renderers.default = 'colab'
import plotly.express as px
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
#Load CSV

df = pd.read_csv('/content/Analysis.csv')

# %%
df
# Out:
#              user        date      time
# 0           kiran    7/1/2022   6:56:23
# 1           kiran    7/1/2022   7:09:53
# 2           kiran    7/1/2022   7:10:40
# 3          raghav    7/1/2022   8:27:30
# 4          raghav    7/1/2022   8:27:31
# ...           ...         ...       ...
# 19629      gattam  12/31/2022  20:27:55
# 19630      deepak  12/31/2022  20:27:58
# 19631      gattam  12/31/2022  20:28:00
# 19632  hema kiran  12/31/2022  20:28:02
# 19633    sasidhar  12/31/2022  20:30:29
#
# [19634 rows x 3 columns]

# %%
#convert date(str) into Datetime object
df['date'] = pd.to_datetime(df['date'])

# %%
#Start and End Date in the dataFrame

df.reset_index()['date'].agg(['min', 'max'])
# Out:
# min   2022-07-01
# max   2022-12-31
# Name: date, dtype: datetime64[ns]

# %%
#convert time(str) into Datetime object

df['time'] = pd.to_datetime(df.time).dt.strftime('%H:%M:%S')

# %%
df['time']
# Out:
# 0        06:56:23
# 1        07:09:53
# 2        07:10:40
# 3        08:27:30
# 4        08:27:31
#            ...
# 19629    20:27:55
# 19630    20:27:58
# 19631    20:28:00
# 19632    20:28:02
# 19633    20:30:29
# Name: time, Length: 19634, dtype: object

# %%
# No.of unique users in the DataFrame

len(df['user'].unique())
# Out:
# 90

# %%
user_df = df['user'].value_counts().to_frame()

# %%
# Minimum Usage User

user_df[user_df['user']==user_df['user'].min()]
# Out:
#        user
# devi      1
# pavan     1
# minna     1

# %%
# Maximum Usage User

user_df[user_df['user']==user_df['user'].max()]
# Out:
#        user
# ketha  2555

# %%
#Per user Request Distribution

fig = px.histogram(df['user']).update_xaxes(categoryorder='total descending')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Date

date_df = df['date'].value_counts().to_frame()

# %%
date_df
# Out:
#             date
# 2022-07-12   438
# 2022-12-21   388
# 2022-08-10   347
# 2022-10-03   339
# 2022-07-13   311
# ...          ...
# 2022-08-06     5
# 2022-07-03     5
# 2022-09-04     5
# 2022-10-15     2
# 2022-09-03     1
#
# [182 rows x 1 columns]

# %%
# Date with Maximum requests

date_df[date_df['date']==date_df['date'].max()]
# Out:
#             date
# 2022-07-12   438

# %%
 # Date with Minimum requests

date_df[date_df['date']==date_df['date'].min()]
# Out:
#             date
# 2022-09-03     1

# %%
# Average requests per day

date_df['date'].mean()
# Out:
# 107.87912087912088

# %%
#Day-wise Request Distribution

fig = px.histogram(df['date'].astype(str).to_list()).update_xaxes(categoryorder='total descending', type='category')
# fig.update_traces(connectgaps=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Time

time_df = df['time'].value_counts().to_frame()

# %%
time_df
# Out:
#           time
# 14:53:25    11
# 13:46:44    10
# 13:23:41    10
# 17:02:58    10
# 14:20:15    10
# ...        ...
# 08:37:54     1
# 08:37:55     1
# 08:44:58     1
# 08:49:47     1
# 20:30:29     1
#
# [14617 rows x 1 columns]

# %%
# Time where we got Maximum requests

time_df[time_df['time']==time_df['time'].max()]
# Out:
#           time
# 14:53:25    11

# %%
# Time where we got Minimum requests

time_df[time_df['time']==time_df['time'].min()]
# Out:
#           time
# 20:30:14     1
# 06:40:05     1
# 22:51:02     1
# 20:54:28     1
# 20:15:11     1
# ...        ...
# 08:37:54     1
# 08:37:55     1
# 08:44:58     1
# 08:49:47     1
# 20:30:29     1
#
# [11719 rows x 1 columns]

# %%
#Time-wise Request Distribution

fig = px.histogram(df['time']).update_xaxes(categoryorder='total descending', type='category')
# fig.update_traces(connectgaps=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#date, user, occurance

dates = df['date'].unique()
users = df['user'].unique().tolist()

# %%
dlist = []
for d in dates:
    
    temp_df = df[df['date']==d]
    for usr in users:
        l = len(temp_df[temp_df['user']==usr])
        if l==0:
            continue
        tdict = {'date': d}
        tdict['user']=usr
        tdict['occurance']=l
        dlist.append(tdict)

# %%
occ_df = pd.DataFrame(dlist, columns = ['date', 'user', 'occurance'])

# %%
occ_df
# Out:
#            date        user  occurance
# 0    2022-07-01       kiran          3
# 1    2022-07-01      raghav         10
# 2    2022-07-01       nikky          2
# 3    2022-07-01        naga          5
# 4    2022-07-01       reddy          2
# ...         ...         ...        ...
# 2841 2022-12-31       nikky          4
# 2842 2022-12-31    sasidhar         10
# 2843 2022-12-31      gattam          4
# 2844 2022-12-31      deepak          2
# 2845 2022-12-31  hema kiran          2
#
# [2846 rows x 3 columns]

# %%
#Scatter plot that shows per user req over date

fig = px.scatter(occ_df, x="date", y="occurance", color="user")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
